# %% [markdown]
# # Notebook 1 — Data Exploration
#
# Download historical OHLCV data, inspect it, and visualize price + volume.

# %%
import sys
sys.path.insert(0, '..')

from src.data.fetcher import DataFetcher
from src.utils.config import load_config
import plotly.graph_objects as go
from plotly.subplots import make_subplots

config = load_config()
config['data']['source'] = 'yfinance'  # Use yfinance for quick exploration (no API key needed)
config['data']['timeframe'] = '1Day'

fetcher = DataFetcher(config)

# %%
# Download daily data for AAPL
df = fetcher.fetch('AAPL', start='2020-01-01', end='2024-12-31')
print(f'Shape: {df.shape}')
df.head(10)
# Out:
# [2026-02-25 00:55:43] INFO src.data.fetcher — Loading cached data for AAPL from C:\Users\Arnold\Desktop\Projects\StockPrediction\data\raw\AAPL_1Day_2020-01-01_2024-12-31.parquet
# Shape: (1257, 5)
#                                 open       high        low      close  \
# datetime
# 2020-01-02 00:00:00-05:00  71.409778  72.460776  71.156674  72.400513
# 2020-01-03 00:00:00-05:00  71.629138  72.455950  71.472454  71.696632
# 2020-01-06 00:00:00-05:00  70.819208  72.306506  70.568510  72.267937
# 2020-01-07 00:00:00-05:00  72.277586  72.533103  71.708703  71.928062
# 2020-01-08 00:00:00-05:00  71.631567  73.386438  71.631567  73.085121
# 2020-01-09 00:00:00-05:00  74.061360  74.830322  73.810669  74.637482
# 2020-01-10 00:00:00-05:00  74.871326  75.370309  74.304848  74.806236
# 2020-01-13 00:00:00-05:00  75.122026  76.430946  75.003904  76.404427
# 2020-01-14 00:00:00-05:00  76.341760  76.551476  75.249786  75.372719
# 2020-01-15 00:00:00-05:00  75.172630  76.052475  74.618202  75.049690
#
#                               volume
# datetime
# 2020-01-02 00:00:00-05:00  135480400
# 2020-01-03 00:00:00-05:00  146322800
# 2020-01-06 00:00:00-05:00  118387200
# 2020-01-07 00:00:00-05:00  108872000
# 2020-01-08 00:00:00-05:00  132079200
# 2020-01-09 00:00:00-05:00  170108400
# 2020-01-10 00:00:00-05:00  140644800
# 2020-01-13 00:00:00-05:00  121532000
# 2020-01-14 00:00:00-05:00  161954400
# 2020-01-15 00:00:00-05:00  121923600

# %%
# Basic statistics
df.describe()
# Out:
#               open         high          low        close        volume
# count  1257.000000  1257.000000  1257.000000  1257.000000  1.257000e+03
# mean    151.283476   152.961786   149.740609   151.439655  9.061168e+07
# std      41.756218    41.955068    41.591866    41.816680  5.324605e+07
# min      55.110034    55.211516    51.372081    54.213600  2.323470e+07
# 25%     125.840231   127.451673   124.349249   126.366211  5.546960e+07
# 50%     149.906112   151.830442   148.084685   150.080338  7.629970e+07
# 75%     175.755193   177.608496   174.476804   175.908401  1.077601e+08
# max     256.787224   258.686851   256.230269   257.612701  4.265100e+08

# %%
# Candlestick chart with volume
fig = make_subplots(rows=2, cols=1, shared_xaxes=True,
                    vertical_spacing=0.03, row_heights=[0.75, 0.25])

fig.add_trace(go.Candlestick(
    x=df.index,
    open=df['open'], high=df['high'],
    low=df['low'], close=df['close'],
    name='OHLC'
), row=1, col=1)

fig.add_trace(go.Bar(
    x=df.index, y=df['volume'], name='Volume', marker_color='rgba(100,149,237,0.5)'
), row=2, col=1)

fig.update_layout(title='AAPL — Daily OHLCV', xaxis_rangeslider_visible=False, height=600)
fig.show()

# %%
# Check for missing values
print('Missing values:')
print(df.isnull().sum())
# Out:
# Missing values:
# open      0
# high      0
# low       0
# close     0
# volume    0
# dtype: int64
